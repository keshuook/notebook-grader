# %%
"""Question 1: Write a Python program to implement a simple calculator with four basic arithmetic operations: 
addition, subtraction, multiplication, and division. The program should get the choice of 
operation from the user (addition/subtraction/multiplication/division) and then get the operands.
At the end, the program should print the result"""



def addition(a,b):
 print("The sum is:",a+b)

def multiplication(a,b):
 print("The product is:",a*b)

def division(a,b):
 print("The quotient is:",a/b)

def subtraction(a,b):
 print("The difference is:",a-b)

while True: 
 a=int(input("\nEnter first number:"))
 b=int(input("Enter second number:"))
 choice=int(input("\nChoose an option\nAddition: 1\nMultiplication: 2\nDivision: 3\nSubtraction: 4\nExit: 5\nCHOICE:"))
 if choice==1:
    addition(a,b)
 elif choice==2:
   multiplication(a,b) 
 elif choice==3:
   division(a,b)
 elif choice==4:
   subtraction(a,b)
 elif choice==5:
     break
 else:
   print("\nEnter a new option")
# Out:
# Enter first number: 1
# Enter second number: 2
#
# Choose an option
# Addition: 1
# Multiplication: 2
# Division: 3
# Subtraction: 4
# Exit: 5
# CHOICE: 3
# The quotient is: 0.5
# Enter first number: 5
# Enter second number: 4
#
# Choose an option
# Addition: 1
# Multiplication: 2
# Division: 3
# Subtraction: 4
# Exit: 5
# CHOICE: 5

# %%
"""Question 2 write a Python program to calculate body mass index (BMI). BMI should be calculated
according to the formula given here: https://www.calculator.net/bmi-calculator.html. The input
height and weight in meters and kilograms, respectively, should be obtained from the user.
● If BMI <= 18.5. Print you are underweight
● If 18.5 < BMI <= 25 . Print yourweight is normal
● If BMI > 25. Print you are overweight."""


h=float(input("Enter Height in meters:"))
w=float(input("Enter Weight in Kilograms:"))
BMI=w/(h**2)
if BMI <= 18.5:
    print("You are underweight")
elif 18.5 < BMI <= 25:
    print("Your weight is normal")
elif BMI > 25:
    print("You are overweight")
# Out:
# Enter Height in meters: 185
# Enter Weight in Kilograms: 80
# You are underweight

# %%
#QUESTION 3
#a) Write a Python program to Extract Unique dictionary values. Create a dictionary on your own to solve this

d= {'first': [1, 2, 3],'second': [3, 4, 5],'third': [4,5,6],'fourth': [5, 6, 7]}
unique=set()
value=d.values()
print(value)
for i in value:
    unique.update(i)
print("\nUnique Values:",unique)
# Out:
# dict_values([[1, 2, 3], [3, 4, 5], [4, 5, 6], [5, 6, 7]])
#
# Unique Values: {1, 2, 3, 4, 5, 6, 7}

# %%
#QUESTION 3
#b) Write a Python program to find if a number is a happy number or not


num = int(input("Enter a number: "))
sum = num
while sum != 1 and sum not in repeated:
     repeated.add(sum)
     string = str(sum)
     sum = 0 
     for i in range(len(string)):
        number = int(string[i])
        sum = sum + (number**2)
    
if sum==1:
    print(f"{num} is a Happy Number!")
else:
    print(f"{num} is not a Happy Number.")
# Out:
# Enter a number:  34
# 34 is not a Happy Number.
